# %% [markdown]
# #Meteostat rifatto

# %%
# !pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/dist-packages (from meteostat) (2.2.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from meteostat) (2024.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from meteostat) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1->meteostat) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.17.0)
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.8

# %%
# Import Meteostat library
from meteostat import Stations
import pandas as pd

# %%
# Catalog of regions
catalog = {
    "Namibia": {
        "lat": -28.038970,
        "lon": 18.105889
    },
    "Namibia_Desert": {
        "lat": -26.6446901,
        "lon": 16.0803984
    },
    "Namibia_Savanna": {
        "lat": -24.9229818,
        "lon": 15.8887668
    },
    "Angola": {
        "lat": -16.949631,
        "lon": 12.332528
    },
    "Saudi_Arabia": {
        "lat": 29.6369064,
        "lon": 38.6245267
    },
    "Kenya": {
        "lat": -1.346889,
        "lon": 36.860099
    },
    "Australia_Mulga": {
        "lat": -23.5358481,
        "lon": 119.8517412
    },
    "Australia_Western": {
        "lat": -23.4186270,
        "lon": 119.8371248
    },
    "Australia_Western_Mulga": {
        "lat": -23.360976,
        "lon": 19.955787
    },
    "Niger": {
        "lat": 15.7289412,
        "lon": 9.0080611
    },
    "Niger_Savanna": {
        "lat": 16.6374777,
        "lon": 6.2709376
    },
    "Chad": {
        "lat": 15.827323,
        "lon": 20.147305
    }
}

# %%
import pandas as pd
from meteostat import Stations

# DataFrame per raccogliere le informazioni delle stazioni
stations_list = []

# Itera su ciascuna località
for region, coordinates in catalog.items():
    lat = coordinates["lat"]
    lon = coordinates["lon"]
    nome_regione = region
    print(f"Processing: {nome_regione}...")

    # Trova la stazione più vicina
    stations = Stations()
    station = stations.nearby(lat, lon)
    nearby_stations = station.fetch(1)  # Limita alla prima stazione

    if not nearby_stations.empty:
        # Ottieni informazioni sulla stazione
        station_info = nearby_stations.iloc[0]
        station_info["region"] = nome_regione
        station_info = station_info.drop(["country", "wmo", "hourly_end", "hourly_start","monthly_start", "monthly_end", "distance"])
        # Concatena i risultati
        stations_list.append(station_info)

    else:
        print(f"No station found for {nome_regione}")

# Creazione del DataFrame
stations_df = pd.DataFrame(stations_list)

# Salva il DataFrame in un file CSV (opzionale)
stations_df.to_csv("stations_df.csv", index=False)
# Out:
# Processing: Namibia...
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Processing: Namibia_Desert...
# Processing: Namibia_Savanna...
# Processing: Angola...
# Processing: Saudi_Arabia...
# Processing: Kenya...
# Processing: Australia_Mulga...
# Processing: Australia_Western...
# Processing: Australia_Western_Mulga...
# Processing: Niger...
# Processing: Niger_Savanna...
# Processing: Chad...
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from meteostat import Daily
from datetime import datetime

# DataFrame per raccogliere i dati climatici
climate_data = pd.DataFrame()

# Itera su ciascuna riga di stations_df
for _, row in stations_df.iterrows():
    if pd.notnull(row["daily_start"]) and pd.notnull(row["daily_end"]):
        nome_regione = row['region']
        station_id = row.name  # Nome della stazione (ID)

        # Convertire le date di inizio e fine in oggetti datetime
        daily_start = row['daily_start']
        daily_end = row['daily_end']

    # Controllare che le date siano valide
    if pd.notnull(daily_start) and pd.notnull(daily_end):

        start = daily_start.to_pydatetime()
        end = daily_end.to_pydatetime()

        start_tuple = (start.year, start.month, start.day)
        end_tuple = (end.year, end.month, end.day)

        start_div = datetime(start_tuple[0], start_tuple[1], start_tuple[2])
        end_div = datetime(end_tuple[0], end_tuple[1], end_tuple[2])

        # Recuperare i dati giornalieri
        data = Daily(station_id, start_div, end_div)
        data = data.fetch()
        data["region"] = nome_regione
        data["start_date"] = daily_start
        data["end_date"] = daily_end

        # Seleziona solo le colonne richieste
        data = data[["region", "start_date", "end_date", "tavg", "tmin", "tmax", "wdir", "wspd", "pres"]].fillna(0)

        # Concatena i dati
        climate_data = pd.concat([climate_data, data])

# Salva i dati climatici in un file CSV
climate_data.to_csv("climate_data.csv", index=False)
# Out:
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.

# %% [markdown]
# #Openmeteopy

# %%
# !pip install git+https://github.com/m0rp43us/openmeteopy
# Out:
# Collecting git+https://github.com/m0rp43us/openmeteopy
#   Cloning https://github.com/m0rp43us/openmeteopy to /tmp/pip-req-build-wkhuk80f
#   Running command git clone --filter=blob:none --quiet https://github.com/m0rp43us/openmeteopy /tmp/pip-req-build-wkhuk80f
#   Resolved https://github.com/m0rp43us/openmeteopy to commit be76f2deabd7ff5ec3f87ebc983091a367e24117
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (2.32.3)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (17.0.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (8.3.4)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (8.1.3)
# Collecting sphinx-rtd-theme (from openmeteopy==0.1.0)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from openmeteopy==0.1.0) (0.45.1)
# Collecting twine (from openmeteopy==0.1.0)
#   Downloading twine-6.1.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->openmeteopy==0.1.0) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->openmeteopy==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->openmeteopy==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.5->openmeteopy==0.1.0) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->openmeteopy==0.1.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->openmeteopy==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->openmeteopy==0.1.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.22.0->openmeteopy==0.1.0) (2024.12.14)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->openmeteopy==0.1.0) (2.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pytest->openmeteopy==0.1.0) (24.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->openmeteopy==0.1.0) (1.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (3.1.5)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.18.0)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx->openmeteopy==0.1.0) (1.4.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->openmeteopy==0.1.0)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting readme-renderer>=35.0 (from twine->openmeteopy==0.1.0)
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from twine->openmeteopy==0.1.0) (1.0.0)
# Requirement already satisfied: keyring>=15.1 in /usr/lib/python3/dist-packages (from twine->openmeteopy==0.1.0) (23.5.0)
# Collecting rfc3986>=1.4.0 (from twine->openmeteopy==0.1.0)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from twine->openmeteopy==0.1.0) (13.9.4)
# Collecting id (from twine->openmeteopy==0.1.0)
#   Downloading id-1.5.0-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx->openmeteopy==0.1.0) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->openmeteopy==0.1.0) (1.17.0)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->openmeteopy==0.1.0)
#   Downloading nh3-0.2.20-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.0 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->twine->openmeteopy==0.1.0) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->openmeteopy==0.1.0) (0.1.2)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 43.9 MB/s eta 0:00:00
# Downloading twine-6.1.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.5 MB/s eta 0:00:00
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 10.0 MB/s eta 0:00:00
# Downloading id-1.5.0-py3-none-any.whl (13 kB)
# Downloading nh3-0.2.20-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (744 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.4/744.4 kB 17.3 MB/s eta 0:00:00
# Building wheels for collected packages: openmeteopy
#   Building wheel for openmeteopy (setup.py) ... done
#   Created wheel for openmeteopy: filename=openmeteopy-0.1.0-py3-none-any.whl size=64551 sha256=9c6589dcaeee764c08564f2005f6b7b1c31ab5d87389c8f7eeeda8eafec66f70
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ylgqr_x8/wheels/53/e4/b5/687b5a6197913f4c83e0c3201bd5d39ce74fff69be9956cfa3
# Successfully built openmeteopy
# Installing collected packages: rfc3986, nh3, readme-renderer, id, twine, sphinxcontrib-jquery, sphinx-rtd-theme, openmeteopy
# Successfully installed id-1.5.0 nh3-0.2.20 openmeteopy-0.1.0 readme-renderer-44.0 rfc3986-2.0.0 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1 twine-6.1.0

# %%
import openmeteopy
from openmeteopy import OpenMeteo
from openmeteopy.hourly import HourlyHistorical
from openmeteopy.daily import DailyHistorical
from openmeteopy.options import HistoricalOptions
from openmeteopy.utils.constants import *
import time

# Date range
start_date = "2020-11-29"
end_date = "2020-11-30"

# Iterate through the catalog
for region, coordinates in catalog.items():
    latitude = coordinates["lat"]
    longitude = coordinates["lon"]

    # Set up OpenMeteo request
    hourly = HourlyHistorical()
    daily = DailyHistorical()
    options = HistoricalOptions(
        latitude,
        longitude,
        start_date=start_date,
        end_date=end_date
    )

    #mgr = OpenMeteo(options, hourly.all(), daily.all())
    mgr = OpenMeteo(options, None, daily.all())

    # Download data
    meteo = mgr.get_pandas()
    meteo_df = meteo[0]

    # Save to CSV
    file_name = f"{region}_meteo_data.csv"
    meteo_df.to_csv(file_name, index=False)
    print(f"Data for {region} saved to {file_name}")

    # Add a delay to avoid exceeding the rate limit
    time.sleep(60) # Wait for 60 seconds before the next request
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f3d5de33f257> in <cell line: 0>()
#      31     # Download data
#      32     meteo = mgr.get_pandas()
# ---> 33     meteo_df = meteo[0]
#      34
#      35     # Save to CSV
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0
